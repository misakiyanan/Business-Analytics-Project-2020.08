# %%
"""
set reordered column in order_product table
"""
# Out:
# '\nset reordered column in order_product table\n'

# %%
import pandas as pd
import numpy as np

# %%
order_products = pd.read_csv("data/order_products.csv")
orders = pd.read_csv("data/orders.csv")
joint = order_products.merge(orders, how="left", on="order_id")
# joint = joint.iloc[:,0:5]
joint
# Out:
#           order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0                2       33120                  1   202279             3
# 1                2       28985                  2   202279             3
# 2                2        9327                  3   202279             3
# 3                2       45918                  4   202279             3
# 4                2       30035                  5   202279             3
# ...            ...         ...                ...      ...           ...
# 33819101   3421063       14233                  3   169679            30
# 33819102   3421063       35548                  4   169679            30
# 33819103   3421070       35951                  1   139822            15
# 33819104   3421070       16953                  2   139822            15
# 33819105   3421070        4724                  3   139822            15
#
#           order_dow  order_hour_of_day  days_since_prior_order
# ...

# %%
grouped = joint.groupby(by=['user_id', 'product_id'])
joint['rank'] = grouped['order_number'].rank(ascending=True)
joint

# ref. https://stackoverflow.com/questions/26720916/faster-way-to-rank-rows-in-subgroups-in-pandas-dataframe
# Out:
#           order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0                2       33120                  1   202279             3
# 1                2       28985                  2   202279             3
# 2                2        9327                  3   202279             3
# 3                2       45918                  4   202279             3
# 4                2       30035                  5   202279             3
# ...            ...         ...                ...      ...           ...
# 33819101   3421063       14233                  3   169679            30
# 33819102   3421063       35548                  4   169679            30
# 33819103   3421070       35951                  1   139822            15
# 33819104   3421070       16953                  2   139822            15
# 33819105   3421070        4724                  3   139822            15
#
#           order_dow  order_hour_of_day  days_since_prior_order  rank
# ...

# %%
joint['reordered'] = 0
joint
# Out:
#           order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0                2       33120                  1   202279             3
# 1                2       28985                  2   202279             3
# 2                2        9327                  3   202279             3
# 3                2       45918                  4   202279             3
# 4                2       30035                  5   202279             3
# ...            ...         ...                ...      ...           ...
# 33819101   3421063       14233                  3   169679            30
# 33819102   3421063       35548                  4   169679            30
# 33819103   3421070       35951                  1   139822            15
# 33819104   3421070       16953                  2   139822            15
# 33819105   3421070        4724                  3   139822            15
#
#           order_dow  order_hour_of_day  days_since_prior_order  rank  \
# ...

# %%
joint.loc[joint['rank'] > 1, 'reordered'] = 1   
# ref.https://stackoverflow.com/questions/49161120/pandas-python-set-value-of-one-column-based-on-value-in-another-column
joint
# Out:
#           order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0                2       33120                  1   202279             3
# 1                2       28985                  2   202279             3
# 2                2        9327                  3   202279             3
# 3                2       45918                  4   202279             3
# 4                2       30035                  5   202279             3
# ...            ...         ...                ...      ...           ...
# 33819101   3421063       14233                  3   169679            30
# 33819102   3421063       35548                  4   169679            30
# 33819103   3421070       35951                  1   139822            15
# 33819104   3421070       16953                  2   139822            15
# 33819105   3421070        4724                  3   139822            15
#
#           order_dow  order_hour_of_day  days_since_prior_order  rank  \
# ...

# %%
zero = joint[joint["reordered"] == 0]
one = joint[joint["reordered"] == 1]
print("number of reordered==0: ", zero.shape[0])
print("number of reordered==1: ", one.shape[0])
# Out:
# number of reordered==0:  13863746
# number of reordered==1:  19955360

# %%
order_products_new = joint.loc[:,order_products.columns.to_list()+['reordered']]

# %%
order_products_new_csv = order_products_new.to_csv("order_products_new.csv", index=False)

# %%
read_file = pd.read_csv("order_products_new.csv")
read_file
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 33819101   3421063       14233                  3          1
# 33819102   3421063       35548                  4          1
# 33819103   3421070       35951                  1          1
# 33819104   3421070       16953                  2          1
# 33819105   3421070        4724                  3          1
#
# [33819106 rows x 4 columns]

# %%
order_products
# Out:
#           order_id  product_id  add_to_cart_order
# 0                2       33120                  1
# 1                2       28985                  2
# 2                2        9327                  3
# 3                2       45918                  4
# 4                2       30035                  5
# ...            ...         ...                ...
# 33819101   3421063       14233                  3
# 33819102   3421063       35548                  4
# 33819103   3421070       35951                  1
# 33819104   3421070       16953                  2
# 33819105   3421070        4724                  3
#
# [33819106 rows x 3 columns]
